# %% [markdown]
# # Exploratory Analysis — Stock Volatility Forecasting
# Walk through data loading, feature engineering, modelling, and evaluation.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))

from src.config import load_config
from src.data_loader import get_data
from src.feature_engineering import build_features
from src.volatility import add_volatility_estimators

cfg = load_config()
raw = get_data(cfg)
feats = build_features(raw, cfg)
feats = add_volatility_estimators(feats)
feats.tail()

# %%
from src.visualization import plot_price_with_indicators
plot_price_with_indicators(feats)

# %%
from src.pipeline import run_pipeline
results = run_pipeline(cfg, include_lstm=False, include_prophet=False)
results['metrics']

# %%
results['backtest'][['equity','buy_hold_equity']].plot(figsize=(14,5), title='Backtest Equity')
